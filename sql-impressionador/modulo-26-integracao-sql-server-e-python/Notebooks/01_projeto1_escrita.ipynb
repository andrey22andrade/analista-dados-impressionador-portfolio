# %%
pip install pyodbc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyodbc

dados_conexao = (
    "Driver={SQL Server};"
    "Server=Andrade;"
    "Database=PythonSQL;"
)
conexao = pyodbc.connect(dados_conexao)
print("Conexão Bem Sucedida")
# Out:
# Conexão Bem Sucedida

# %%
cursor = conexao.cursor()

# comando = """INSERT INTO Vendas(id_venda, data_venda, cliente, produto, preco, quantidade)
# VALUES (3, '13/05/2022', 'Carla', 'Tablet', 1200, 1)"""

id = 5
data = "17/06/2022"
cliente = "Erica"
produto = "Celular"
preco = 1500
quantidade = 1

comando = f"""INSERT INTO Vendas(id_venda, data_venda, cliente, produto, preco, quantidade)
VALUES ({id}, '{data}', '{cliente}', '{produto}', {preco}, {quantidade})"""

cursor.execute(comando)

cursor.commit()
